# %% [markdown]
# # OCT Image Analysis Pipeline
# Retinal Layer Segmentation & Disease Classification

# %%
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from src.datasets import OCTDataset

print('OCT Analysis Pipeline - Walkthrough')
